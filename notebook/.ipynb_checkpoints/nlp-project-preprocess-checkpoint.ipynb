# %% [markdown]
# **1. Load JSON file**<Br>
# **2. Data Exploration and Visualization**<br>
# **3. Select variables and Convert into CSV**<br>
# **4. Text Preprocessing**
# > a) Change to lower cases<Br>
# > b) Transform links (tentative?)<br>
# > c) Remove punctuation<br>
# > d) Remove stop words<br>
# > e) Stem words (to root forms)<br>

# %% [markdown]
# ## **1. Loading JSON file**

# %%
import numpy as np
import pandas as pd
import os
import json
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
# %matplotlib inline
inline_rc = dict(mpl.rcParams)
from tqdm import tqdm
# Out:
# /Users/imbottlebird/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   if sys.path[0] == '':

# %%
#True: all data (about 8 mil), False: 100,000 data
full_data = False

reviews = []
with open('../../yelp_data/yelp_academic_dataset_review.json') as f:
#    f = subset(f, stars != 3)
    for i, line in tqdm(enumerate(f)):
        reviews.append(json.loads(line))
        if full_data==False and i+1 >= 500000:
            break

df_review = pd.DataFrame(reviews)
df_review.tail()
# Out:
# 0it [00:00, ?it/s]
# 1339it [00:00, 13349.40it/s]
# 3044it [00:00, 10246.24it/s]
# 4812it [00:00, 11527.64it/s]
# 6705it [00:00, 11327.02it/s]
# 8498it [00:00, 12732.87it/s]
# 10012it [00:00, 13277.39it/s]
# 11274it [00:01, 8931.15it/s]
# 12309it [00:01, 8241.64it/s]
# 13243it [00:01, 6735.05it/s]
# 14039it [00:01, 6614.29it/s]
# 14787it [00:01, 6709.13it/s]
# 15519it [00:01, 6034.35it/s]
# 16275it [00:01, 6423.09it/s]
# 18953it [00:02, 8320.41it/s]
# 20238it [00:02, 7706.82it/s]
# 21335it [00:02, 7669.96it/s]
# 22331it [00:02, 7145.89it/s]
# 23213it [00:02, 4952.85it/s]
# 23917it [00:02, 5305.81it/s]
# 25422it [00:03, 5531.14it/s]
# 26476it [00:03, 5750.19it/s]
# 28634it [00:03, 6707.11it/s]
# 29421it [00:03, 6490.45it/s]
# 30682it [00:03, 7595.92it/s]
# 31799it [00:03, 8392.08it/s]
# 33445it [00:04, 8381.15it/s]
# 34366it [00:04, 8315.58it/s]
# 36158it [00:04, 8124.56it/s]
# 39736it [00:04, 10577.12it/s]
# 41565it [00:04, 12108.94it/s]
# 43284it [00:04, 12118.37it/s]
# 46656it [00:04, 15001.26it/s]
# 48765it [00:04, 16261.17it/s]
# 52692it [00:05, 19728.37it/s]
# 56486it [00:05, 23046.71it/s]
# 59558it [00:05, 24912.62it/s]
# 62568it [00:05, 24216.94it/s]
# 65357it [00:05, 24274.25it/s]
# 69686it [00:05, 27957.96it/s]
# 72864it [00:05, 28539.89it/s]
# 75989it [00:05, 28167.90it/s]
# 78997it [00:05, 27792.51it/s]
# 82111it [00:06, 28473.35it/s]
# 85057it [00:06, 28679.93it/s]
# 87995it [00:06, 28600.84it/s]
# 90904it [00:06, 26946.25it/s]
# 93653it [00:06, 13992.69it/s]
# 95902it [00:06, 15723.79it/s]
# 98051it [00:07, 14698.53it/s]
# 100478it [00:07, 16670.49it/s]
# 103543it [00:07, 19305.24it/s]
# 105895it [00:07, 19416.64it/s]
# 108132it [00:07, 18303.49it/s]
# 110182it [00:07, 16753.19it/s]
# 112037it [00:07, 15085.50it/s]
# 113703it [00:07, 15131.09it/s]
# 115326it [00:08, 14682.00it/s]
# 116875it [00:08, 13989.19it/s]
# 118337it [00:08, 13664.23it/s]
# 120308it [00:08, 15045.96it/s]
# 121888it [00:08, 11934.67it/s]
# 125388it [00:08, 14875.34it/s]
# 128978it [00:08, 18040.90it/s]
# 132534it [00:08, 21101.97it/s]
# 135311it [00:09, 22490.86it/s]
# 138052it [00:09, 19770.88it/s]
# 141214it [00:09, 22275.04it/s]
# 145269it [00:09, 25757.15it/s]
# 148652it [00:09, 27591.14it/s]
# 152508it [00:09, 30165.29it/s]
# 155853it [00:09, 29746.10it/s]
# 159457it [00:09, 31389.86it/s]
# 162927it [00:09, 32314.28it/s]
# 166296it [00:10, 31406.61it/s]
# 169539it [00:10, 30176.17it/s]
# 172639it [00:10, 26039.94it/s]
# 175882it [00:10, 27675.01it/s]
# 179161it [00:10, 29033.34it/s]
# 183567it [00:10, 32341.87it/s]
# 187001it [00:10, 31917.86it/s]
# 190334it [00:10, 32183.16it/s]
# 195050it [00:10, 35570.52it/s]
# 198787it [00:11, 33032.50it/s]
# 202253it [00:11, 32772.12it/s]
# 205645it [00:11, 32812.90it/s]
# 209007it [00:11, 32602.58it/s]
# 212324it [00:11, 31304.53it/s]
# 215505it [00:11, 30440.99it/s]
# 218737it [00:11, 30979.57it/s]
# 222340it [00:11, 32339.50it/s]
# 226113it [00:11, 33787.49it/s]
# 229728it [00:12, 34461.70it/s]
# 233208it [00:12, 25275.25it/s]
# 236112it [00:12, 20587.33it/s]
# 238576it [00:12, 12059.87it/s]
# 240485it [00:13, 10811.28it/s]
# 242082it [00:13, 11718.90it/s]
# 243638it [00:13, 11233.70it/s]
# 245949it [00:13, 13281.17it/s]
# 247620it [00:13, 13320.72it/s]
# 249192it [00:13, 12518.38it/s]
# 250622it [00:13, 11606.53it/s]
# 252300it [00:13, 11803.65it/s]
# 253578it [00:14, 10357.58it/s]
# 255929it [00:14, 12446.50it/s]
# 257430it [00:14, 11068.19it/s]
# 258745it [00:14, 9759.55it/s]
# 261288it [00:14, 11972.87it/s]
# 262856it [00:14, 12855.96it/s]
# 264420it [00:14, 11149.56it/s]
# 265770it [00:15, 9922.35it/s]
# 266952it [00:15, 10262.58it/s]
# 268114it [00:15, 10277.50it/s]
# 269487it [00:15, 10909.72it/s]
# 270931it [00:15, 11740.80it/s]
# 272830it [00:15, 12856.66it/s]
# 274198it [00:15, 12590.52it/s]
# 275516it [00:15, 12240.97it/s]
# 280294it [00:15, 15756.99it/s]
# 285757it [00:16, 20033.35it/s]
# 289404it [00:16, 23163.88it/s]
# 294151it [00:16, 27366.65it/s]
# 297940it [00:16, 28646.05it/s]
# 302156it [00:16, 31693.07it/s]
# 305953it [00:16, 32453.00it/s]
# 309642it [00:16, 32855.35it/s]
# 313240it [00:16, 30774.00it/s]
# 316820it [00:16, 31527.02it/s]
# 320149it [00:17, 30194.44it/s]
# 324127it [00:17, 32541.02it/s]
# 327528it [00:17, 31037.39it/s]
# 330749it [00:17, 30094.03it/s]
# 333847it [00:17, 30129.77it/s]
# 336922it [00:17, 29325.30it/s]
# 340023it [00:17, 29766.35it/s]
# 344317it [00:17, 32783.62it/s]
# 347714it [00:17, 31271.25it/s]
# 350939it [00:18, 30238.55it/s]
# 354039it [00:18, 28441.96it/s]
# 357123it [00:18, 29120.95it/s]
# 360092it [00:18, 27520.40it/s]
# 362902it [00:18, 24808.04it/s]
# 366081it [00:18, 26548.40it/s]
# 368834it [00:18, 26255.45it/s]
# 371529it [00:18, 24294.86it/s]
# 374037it [00:19, 24447.38it/s]
# 376537it [00:19, 23624.26it/s]
# 378946it [00:19, 23760.83it/s]
# 382083it [00:19, 25624.75it/s]
# 384709it [00:19, 25525.75it/s]
# 388092it [00:19, 27514.39it/s]
# 390919it [00:19, 26730.51it/s]
# 393650it [00:19, 26661.45it/s]
# 397852it [00:19, 29944.90it/s]
# 401566it [00:19, 31762.63it/s]
# 404885it [00:20, 30550.62it/s]
# 408050it [00:20, 30565.01it/s]
# 411523it [00:20, 31704.99it/s]
# 416280it [00:20, 35131.46it/s]
# 420300it [00:20, 36509.75it/s]
# 424078it [00:20, 35267.19it/s]
# 429215it [00:20, 38927.19it/s]
# 433998it [00:20, 41229.37it/s]
# 438875it [00:20, 43015.39it/s]
# 443314it [00:20, 43096.42it/s]
# 447720it [00:21, 42961.75it/s]
# 452458it [00:21, 44197.96it/s]
# 456934it [00:21, 43456.05it/s]
# 461322it [00:21, 41051.82it/s]
# 465484it [00:21, 39335.26it/s]
# 469473it [00:21, 38559.39it/s]
# 473371it [00:21, 38041.87it/s]
# 477207it [00:21, 36975.48it/s]
# 480943it [00:21, 37089.56it/s]
# 485302it [00:22, 38826.18it/s]
# 490276it [00:22, 41560.97it/s]
# 494511it [00:22, 41493.61it/s]
# 498761it [00:22, 41790.23it/s]
#                    business_id  cool                 date  funny  \
# 499995  IhNASEZ3XnBHmuuVnWdIwA     6  2015-09-16 20:35:38      3
# 499996  IhNASEZ3XnBHmuuVnWdIwA     3  2018-11-24 20:09:14      2
# 499997  7HbKKqXtZUjf6uVSHZ8wyw     0  2019-04-20 00:16:42      0
# 499998  DvelUmIuBmfbt95frynYsA     0  2019-03-29 20:59:54      0
# 499999  lmxA0dJM0XsPCIHPXhEQ-g     0  2016-09-01 22:27:17      0
#
#                      review_id  stars  \
# 499995  WNOssTyTI6n_ujQgvC-HVw    5.0
# 499996  7KIqIT0LVr6CWD2U-rph9Q    5.0
# 499997  rl1GMcBPXipF0eWi7jk-eA    5.0
# 499998  K4sTnu0SxtGrtuyMBXPfrw    3.0
# 499999  GtyzHp0CG3qhWWDpXROoUw    5.0
#
#                                                      text  useful  \
# 499995  Other than Kung Fu Tea, I haven't had amazing ...       8
# 499996  I wish they had one in the westside or for thi...       5
# 499997  This will be our new favorite spot. Dylan our ...       0
# 499998  3.5 Stars\n\nEnvironment: The decor is poor, f...       1
# 499999  I want to tell everyone about an experience I ...       0
#
#                        user_id
# 499995  C_CqWSkpn2aOnUXtHx0-iw
# 499996  9-YU-svmnMfKs_DkcZc0Tg
# 499997  6ex5OsJkv1wugjL9BmG9jQ
# 499998  7A00Z3xfN7gjp4RcOeWdfQ
# 499999  jK1ofUrIeJEDZ-6NxA28Gw
# 498761it [00:35, 41790.23it/s]

# %%
#first 100,000 business data

biz=[]
with open('../../yelp_data/yelp_academic_dataset_business.json') as f1:
    for i, line in tqdm(enumerate(f1)):
        biz.append(json.loads(line))
        if full_data==False and i+1 >= 500000:
            break
df_biz = pd.DataFrame(biz)
df_biz.tail()
# Out:
# 0it [00:00, ?it/s]
# 2882it [00:00, 28815.42it/s]
# 3888it [00:00, 14641.90it/s]
# 4698it [00:00, 10114.80it/s]
# 5732it [00:00, 10181.29it/s]
# 6563it [00:00, 9324.64it/s]
# 7379it [00:00, 6202.28it/s]
# 8054it [00:00, 6292.32it/s]
# 8722it [00:01, 5628.57it/s]
# 9326it [00:01, 5137.42it/s]
# 10015it [00:01, 4190.23it/s]
# 10695it [00:01, 4522.67it/s]
# 11193it [00:01, 4438.45it/s]
# 11957it [00:01, 5076.64it/s]
# 12575it [00:01, 4703.49it/s]
# 13161it [00:02, 4847.66it/s]
# 14249it [00:02, 5689.59it/s]
# 14984it [00:02, 5054.36it/s]
# 15991it [00:02, 5908.81it/s]
# 17275it [00:02, 6669.51it/s]
# 18048it [00:02, 5710.06it/s]
# 19347it [00:02, 6614.09it/s]
# 20512it [00:03, 7599.43it/s]
# 21942it [00:03, 8842.03it/s]
# 23000it [00:03, 8484.42it/s]
# 23973it [00:03, 5944.39it/s]
# 25236it [00:03, 6171.99it/s]
# 25990it [00:03, 6196.57it/s]
# 27869it [00:04, 6911.30it/s]
# 28738it [00:04, 6661.26it/s]
# 29472it [00:04, 3030.01it/s]
# 30385it [00:04, 3789.55it/s]
# 31047it [00:05, 3437.84it/s]
# 32244it [00:05, 4292.94it/s]
# 33511it [00:05, 5282.72it/s]
# 34338it [00:05, 4210.02it/s]
# 35338it [00:05, 5094.41it/s]
# 37004it [00:05, 6434.47it/s]
# 38039it [00:05, 7256.05it/s]
# 40398it [00:05, 9158.34it/s]
# 41830it [00:06, 9569.43it/s]
# 44308it [00:06, 11729.03it/s]
# 45978it [00:06, 8331.32it/s]
# 47296it [00:06, 8885.44it/s]
# 48534it [00:06, 9222.56it/s]
# 49821it [00:06, 10079.35it/s]
# 51027it [00:07, 10088.22it/s]
# 52174it [00:07, 8918.71it/s]
# 53546it [00:07, 9821.89it/s]
# 54644it [00:07, 9891.33it/s]
# 56029it [00:07, 10818.58it/s]
# 57690it [00:07, 12082.41it/s]
# 59430it [00:07, 13301.76it/s]
# 61224it [00:07, 14419.50it/s]
# 63211it [00:07, 15699.96it/s]
# 65321it [00:07, 17004.92it/s]
# 67128it [00:08, 17126.59it/s]
# 68916it [00:08, 16424.25it/s]
# 71167it [00:08, 17873.88it/s]
# 73671it [00:08, 15261.83it/s]
# 75855it [00:08, 16777.22it/s]
# 77664it [00:08, 16591.22it/s]
# 79792it [00:08, 17699.98it/s]
# 82611it [00:08, 19923.93it/s]
# 84905it [00:09, 20738.69it/s]
# 87094it [00:09, 20544.23it/s]
# 89230it [00:09, 19499.88it/s]
# 91248it [00:09, 17612.65it/s]
# 93092it [00:09, 17378.25it/s]
# 95237it [00:09, 18426.76it/s]
# 97138it [00:09, 18404.56it/s]
# 99046it [00:09, 18472.76it/s]
# 100922it [00:09, 18411.89it/s]
# 102784it [00:10, 16399.60it/s]
# 104479it [00:10, 16178.51it/s]
# 106136it [00:10, 15425.27it/s]
# 107797it [00:10, 15762.02it/s]
# 109400it [00:10, 14975.74it/s]
# 110925it [00:10, 12744.64it/s]
# 112997it [00:10, 14408.07it/s]
# 115648it [00:10, 16694.03it/s]
# 117541it [00:10, 17135.68it/s]
# 120122it [00:11, 19055.93it/s]
# 122712it [00:11, 20641.39it/s]
# 125292it [00:11, 21958.08it/s]
# 127626it [00:11, 20127.13it/s]
# 129765it [00:11, 18725.43it/s]
# 131746it [00:11, 11971.80it/s]
# 134001it [00:11, 13901.75it/s]
# 136476it [00:12, 16006.48it/s]
# 138462it [00:12, 16523.19it/s]
# 140388it [00:12, 16687.36it/s]
# 142249it [00:12, 14808.67it/s]
# 143904it [00:12, 13208.97it/s]
# 145379it [00:12, 13468.28it/s]
# 147055it [00:12, 14310.99it/s]
# 148925it [00:12, 15394.56it/s]
# 150552it [00:13, 15390.75it/s]
# 152152it [00:13, 15115.31it/s]
# 153800it [00:13, 15500.03it/s]
# 155383it [00:13, 15404.86it/s]
# 157239it [00:13, 16232.08it/s]
# 159336it [00:13, 17412.04it/s]
# 161121it [00:13, 17085.33it/s]
# 163145it [00:13, 17923.03it/s]
# 164971it [00:13, 17249.71it/s]
# 166725it [00:13, 16526.55it/s]
# 168506it [00:14, 16890.92it/s]
# 170624it [00:14, 17983.35it/s]
# 172457it [00:14, 17261.73it/s]
# 174258it [00:14, 17478.23it/s]
# 176305it [00:14, 18278.21it/s]
# 178158it [00:14, 17239.42it/s]
# 179912it [00:14, 17309.32it/s]
# 182538it [00:14, 19280.36it/s]
# 184959it [00:14, 20534.12it/s]
# 187320it [00:15, 21368.62it/s]
# 190084it [00:15, 22929.23it/s]
# 193145it [00:15, 24795.00it/s]
# 196736it [00:15, 27332.19it/s]
# 199618it [00:15, 27729.54it/s]
# 202497it [00:16, 8674.08it/s]
# 205174it [00:16, 10880.36it/s]
# 207458it [00:16, 10044.02it/s]
# 209393it [00:16, 12520.51it/s]
#                                 address  \
# 209388                 9750 Weston Road
# 209389              3240 Wilkinson Blvd
# 209390          7014-590 E Camelback Rd
# 209391
# 209392  21 St Clair Avenue E, Suite 401
#
#                                                attributes  \
# 209388  {'Ambience': '{'romantic': False, 'intimate': ...
# 209389  {'RestaurantsPriceRange2': '1', 'BusinessParki...
# 209390  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 209391                                               None
# 209392                                               None
#
#                    business_id  \
# 209388  9Q0fPWAjUweoFDk0kafuzQ
# 209389  PotiAhtDMYMNsJCzV0oLAw
# 209390  SYa2j1boLF8DcGVOYfHPcA
# 209391  RSSIsgO00OuWQTRoITacpA
# 209392  tOcYmewXFhQeZh3V42ymwg
#
#                                                categories          city  \
# 209388                  Japanese, Sushi Bars, Restaurants       Vaughan
# 209389  Department Stores, Food, Mobile Phones, Fashio...     Charlotte
# 209390  American (New), Food, Burgers, Restaurants, Fa...    Scottsdale
# 209391                   Pet Services, Pet Training, Pets  Indian Trail
# 209392  Tax Services, Professional Services, Accountan...       Toronto
#
#                                                     hours  is_open   latitude  \
# 209388  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        0  43.838555
# 209389                                               None        0  35.226307
# 209390  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...        1  33.504062
# 209391  {'Monday': '0:0-0:0', 'Tuesday': '7:0-19:0', '...        1  35.101965
# 209392  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...        1  43.688214
#
#          longitude                       name postal_code  review_count  \
# 209388  -79.559823                Nishi Sushi     L4H 2P2             5
# 209389  -80.893539                    Walmart       28208            13
# 209390 -111.929431                  Five Guys       85251            97
# 209391  -80.599385  Indian Trail Dog Training       28079             3
# 209392  -79.392756                  Kudlow Ye     M4T 1L9             3
#
#         stars state
# 209388    4.0    ON
# 209389    2.0    NC
# 209390    3.5    AZ
# 209391    5.0    NC
# 209392    5.0    ON

# %%
#user data

user=[]
with open('../../yelp_data/yelp_academic_dataset_user.json') as f1:
    for i, line in tqdm(enumerate(f1)):
        user.append(json.loads(line))
        if full_data==False and i+1 >= 10000:
            break
df_user = pd.DataFrame(user)
df_user.tail()
# Out:
# 0it [00:00, ?it/s]
# 1176it [00:00, 11731.26it/s]
# 2895it [00:00, 12966.29it/s]
# 4509it [00:00, 13775.72it/s]
# 5527it [00:00, 12058.15it/s]
# 6520it [00:00, 11091.30it/s]
# 7495it [00:00, 8824.36it/s]
# 8938it [00:00, 9987.74it/s]
#       average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 9995           4.28                1                1                 1
# 9996           3.96                0                1                 0
# 9997           3.17                2                2                 2
# 9998           4.37               12                0                12
# 9999           4.12                0                1                 0
#
#       compliment_hot  compliment_list  compliment_more  compliment_note  \
# 9995               0                0                0                4
# 9996               0                0                0                1
# 9997               4                0                0                7
# 9998               5                1                5                9
# 9999               1                0                0                0
#
#       compliment_photos  compliment_plain  ...  cool  \
# 9995                  1                 5  ...    84
# 9996                  0                 0  ...    12
# 9997                  2                 2  ...    60
# 9998                  4                15  ...   293
# 9999                  0                 0  ...     5
#
#                                         elite  fans  \
# 9995                                              6
# 9996                                              2
# 9997                                2009,2010     4
# 9998  2011,2012,2013,2014,2015,2016,2017,2018    20
# 9999                                              1
#
#                                                 friends  funny      name  \
# 9995  oCsUv4I1KOE5TZs9fZSnwg, yOW8XfUxz-0xjQ9BydzG6A...     18    Brooke
# 9996  jwuC6A11X-JHmvZfyCGJng, BgQ5CdjED5TYXi73ecBviA...     12      Jose
# 9997  JSm522HyV4IfzHWlvwonuQ, qVc8ODYU5SZjKXVBgXdI7w...    133    Missie
# 9998  itD9UJX9xlp7fzw_7aTaHg, VinA5Nlf2qSo2uNWvnrsfA...    165  Caroline
# 9999  bPMhW4pV_GuvYuUIByX8eg, cJwXPcngH-0IpEaQpAg3Tg...      7        Mr
#
#       review_count useful                 user_id        yelping_since
# 9995            96    167  6OM81aboI0ijH0MgeGCJNA  2011-05-11 18:02:36
# 9996            45     52  C28YINow3Dcvm9D4PwAknQ  2008-01-05 07:54:03
# 9997           147    228  bH0ec25L7Yaladd2JyLRwg  2008-02-18 08:09:59
# 9998           487    574  CBcVLRQBySr3IdjLB5jOwA  2009-07-03 04:49:38
# 9999            26     20  YO-4qGvk57ytVYD4E8ChlQ  2008-11-07 17:22:50
#
# [5 rows x 22 columns]

# %% [markdown]
# ## **2. Data Exloration and Visualization**

# %%
x=df_review['stars'].value_counts()
x=x.sort_index()

#plot star rating distribution
plt.figure(figsize=(6,5))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Star Rating Distribution", fontsize=16)
plt.ylabel('Number of businesses')
plt.xlabel('Star Ratings')
# Out:
# Text(0.5, 0, 'Star Ratings')

# %%
biz_cat = ''.join(df_biz['categories'].astype('str'))

cats=pd.DataFrame(biz_cat.split(','),columns=['categories'])

#prep for chart
x=cats.categories.value_counts()
x=x.sort_values(ascending=False)
x=x.iloc[0:20]

#chart
plt.figure(figsize=(16,4))
ax = sns.barplot(x.index, x.values, alpha=0.8)#,color=color[5])
plt.title("Top business categories",fontsize=25)
locs, labels = plt.xticks()
plt.setp(labels, rotation=80)
plt.ylabel('Number of businesses', fontsize=12)
plt.xlabel('Category', fontsize=12)

plt.show()

# %% [markdown]
# ## **3. Select Variables and Convert into CSV**

# %% [markdown]
# Issues for consideration:<br>
# Are we going to pick an industry, then work with the subset businesses? Or we do not consider the industry? e.g. cafe, restaurant, hair salon, etc.

# %%
# Replace business_id with businesss name
# Selected three variables: business_name, stars, text

df_comb=df_review.copy()
#df_comb['business_id'] = df_comb['business_id'].map(df_biz.set_index('business_id')['name'])
#df_comb = df_comb.rename(columns = {"business_id":"business_name"})[['business_name','stars','text']]

df_comb['business_name'] = df_comb['business_id'].map(df_biz.set_index('business_id')['name'])
df_comb = df_comb[['business_name','stars','text']]
df_comb
# Out:
#                                business_name  stars  \
# 0               Bellagio Gallery of Fine Art    2.0
# 1                             Rio Hair Salon    1.0
# 2                     Deagan's Kitchen & Bar    5.0
# 3                    Cabo Mexican Restaurant    1.0
# 4             Raising Cane's Chicken Fingers    4.0
# 5                             Firehouse Subs    5.0
# 6                             Chon Thai Food    5.0
# 7       Centennial Dermatology & Skin Cancer    5.0
# 8                                   Casa Mia    5.0
# 9                         The Urban Tea Loft    4.0
# 10                           Maria's Tailors    5.0
# 11                     The Wokker Restaurant    4.0
# 12                    BOHO Furniture Gallery    5.0
# 13              SN Pacific Rim Asian Kitchen    5.0
# 14                          Black Cab & Limo    5.0
# 15                                  PoolServ    1.0
# 16                                 Pink Taco    1.0
# 17                       Choolaah Indian BBQ    4.0
# 18                         Findlay Chevrolet    1.0
# 19                          Angry Crab Shack    3.0
# 20                           Fairmount Bagel    5.0
# 21                                 Pink Taco    5.0
# 22                       Coconut's Fish Cafe    4.0
# 23                            Desert Fitness    5.0
# 24                                Mesa Grill    4.0
# 25                                   Levetto    4.0
# 26                           El Güero Canelo    4.0
# 27                              Vito's Pizza    4.0
# 28                        Sal's Tuscan Grill    5.0
# 29                        Buffalo Wild Wings    1.0
# ...                                      ...    ...
# 499970                         Panda Express    1.0
# 499971                           Nuit Social    5.0
# 499972          Goodyear Auto Service Center    5.0
# 499973              Legion Brewing SouthPark    5.0
# 499974                                  Cibo    2.0
# 499975                     Apartment Hunters    1.0
# 499976                      McKnight Kitchen    5.0
# 499977                   Blue Martini Lounge    1.0
# 499978                   Bulldog Liquidators    5.0
# 499979              Servisair Chinook Lounge    2.0
# 499980                      Sun Auto Service    5.0
# 499981    Chef Kennys Asian Vegan Restaurant    5.0
# 499982                         Apple Factory    2.0
# 499983                     Annex Ale Project    5.0
# 499984             Retreat at McAlpine Creek    1.0
# 499985                               Bouchon    1.0
# 499986                     Bomba Tacos & Rum    4.0
# 499987                        Westar Laundry    5.0
# 499988                       KoJa Restaurant    1.0
# 499989                       Sunbrite Dental    5.0
# 499990                           M J  Donuts    5.0
# 499991                               Nanny's    5.0
# 499992                Las Vegas Pest Control    5.0
# 499993                      Climate Pro, LLC    5.0
# 499994               TasteBuds Frozen Yogurt    5.0
# 499995                          Brew Tea Bar    5.0
# 499996                          Brew Tea Bar    5.0
# 499997                       Let's Meat Kbbq    5.0
# 499998                Yummy Dumpling and BBQ    3.0
# 499999                              Sake Rok    5.0
#
#                                                      text
# 0       As someone who has worked with many museums, I...
# 1       I am actually horrified this place is still in...
# 2       I love Deagan's. I do. I really do. The atmosp...
# 3       Dismal, lukewarm, defrosted-tasting "TexMex" g...
# 4       Oh happy day, finally have a Canes near my cas...
# 5       This is definitely my favorite fast food sub s...
# 6       Really good place with simple decor, amazing f...
# 7       Awesome office and staff, very professional an...
# 8       Most delicious authentic Italian I've had in t...
# 9       I have been here twice. Very nice and laid bac...
# 10      Maria is VERY good at what she does with great...
# 11      ORDER In (Delivery) Review\n\nI discovered thi...
# 12      We purchased new office furniture from this lo...
# 13      Everything that my husband and I tried today w...
# 14      Called for a 5:15 morning reservation. The dri...
# 15      If I could give less than one star, that would...
# 16      10pm on a super bowl Sunday and they're alread...
# 17      A close friend was in town and so instead of t...
# 18      Tried to have my car repaired.  Even made an a...
# 19      My husband and I go there once a week since la...
# 20      AMAZING. Simply amazing. Believe all of the hy...
# 21      Holy heck this place is amazing. I love their ...
# 22      Coconut's Fish Cafe is a fantastic, Five Stars...
# 23      I love the classes at this gym. Zumba and. Rad...
# 24      As the previous person posted, what more can r...
# 25      In the heart of Chinatown, I discovered it enr...
# 26      Always a fun outing to come for great hot dogs...
# 27      Was a Chicago style deep dish.  Homemade type ...
# 28      First time eating there and everything was so ...
# 29      Just... not good.  We want it to be - we have ...
# ...                                                   ...
# 499970  I have never been at a slower panda express.  ...
# 499971  Came here fresh from Toronto Pearson, for a sn...
# 499972  I was treated very well by Barry and Chris. I ...
# 499973  Having gone here for brunch, I was super excit...
# 499974  My wife and I had the 'just passable' 3-part l...
# 499975  We have had numerous issues with the property ...
# 499976  We went here for date night and it was a absol...
# 499977  Worse experience I've ever had. After spending...
# 499978  Got all kinds of great stuff here. I was able ...
# 499979  Although this lounge is spacious and normally ...
# 499980  I always get my auto work done here. Plain and...
# 499981  OMG!! Chef Kenny is the best!! I love this pla...
# 499982  I realized this weekend that summer is almost ...
# 499983  So these guys are like, "let's brew some aweso...
# 499984  I have lived here for almost 2 years... and on...
# 499985  I frequent Bouchon almost every time I make a ...
# 499986  Great service. All right food. Large and/or sm...
# 499987  I was recently staying at a local hospital and...
# 499988  GROSS FISH!\n\nWent here for lunch and ordered...
# 499989  This rating is long overdue, but here it comes...
# 499990  Great donuts. \nThe best coffee ever.\nLess th...
# 499991  Great spot. Delicious paninis and salads. Huge...
# 499992  Since using Las Vegas pest control I haven't s...
# 499993  Incredible experience with Jordan today.  He c...
# 499994  This is my favorite froyo place! I'm usually a...
# 499995  Other than Kung Fu Tea, I haven't had amazing ...
# 499996  I wish they had one in the westside or for thi...
# 499997  This will be our new favorite spot. Dylan our ...
# 499998  3.5 Stars\n\nEnvironment: The decor is poor, f...
# 499999  I want to tell everyone about an experience I ...
#
# [500000 rows x 3 columns]

# %%
#plot 20 most reviewed business
x=df_comb['business_name'].value_counts()
x=x.sort_values(ascending=False)
x=x.iloc[0:20]

#plot chart
plt.figure(figsize=(16,8))
ax = sns.barplot(x.index, x.values, alpha=0.8)#,color=color[5])
plt.title("20 Most Reviewed Businesses",fontsize=20)
locs, labels = plt.xticks()
plt.setp(labels, rotation=80)
plt.ylabel('Number of reviews', fontsize=20)
plt.xlabel('Business', fontsize=20)
plt.show()

# %% [markdown]
# ### Conversion into CSV

# %%
#Convert review, business, user datasets into CSV
#df_review.to_csv('data/yelp_reviews.csv', index=False)
#df_biz.to_csv('data/yelp_business.csv', index=False)
#df_user.to_csv('data/yelp_user.csv', index=False)
#df_comb.to_csv('../../yelp_data/yelp_reviews.csv', index=False)

# %% [markdown]
# ## **4. Text Preprocessing**

# %% [markdown]
# #### **Preprocessing steps:**
# Sentiment analysis:<br>
# >a) Change to lower cases<Br>
# >b) Remove HTML<br>
# >c) Remove punctuation & Tokenize<br>
# >d) Remove stop words<br>
# >e) Lemmatization or Stemming<br>

# %%
df_comb['text']
# Out:
# 0         As someone who has worked with many museums, I...
# 1         I am actually horrified this place is still in...
# 2         I love Deagan's. I do. I really do. The atmosp...
# 3         Dismal, lukewarm, defrosted-tasting "TexMex" g...
# 4         Oh happy day, finally have a Canes near my cas...
#                                 ...
# 499995    Other than Kung Fu Tea, I haven't had amazing ...
# 499996    I wish they had one in the westside or for thi...
# 499997    This will be our new favorite spot. Dylan our ...
# 499998    3.5 Stars\n\nEnvironment: The decor is poor, f...
# 499999    I want to tell everyone about an experience I ...
# Name: text, Length: 500000, dtype: object

# %%
#limit the number of strings
df_pre=df_comb.copy()
df_pre
# Out:
#                          business_name  stars  \
# 0         Bellagio Gallery of Fine Art    2.0
# 1                       Rio Hair Salon    1.0
# 2               Deagan's Kitchen & Bar    5.0
# 3              Cabo Mexican Restaurant    1.0
# 4       Raising Cane's Chicken Fingers    4.0
# ...                                ...    ...
# 499995                    Brew Tea Bar    5.0
# 499996                    Brew Tea Bar    5.0
# 499997                 Let's Meat Kbbq    5.0
# 499998          Yummy Dumpling and BBQ    3.0
# 499999                        Sake Rok    5.0
#
#                                                      text
# 0       As someone who has worked with many museums, I...
# 1       I am actually horrified this place is still in...
# 2       I love Deagan's. I do. I really do. The atmosp...
# 3       Dismal, lukewarm, defrosted-tasting "TexMex" g...
# 4       Oh happy day, finally have a Canes near my cas...
# ...                                                   ...
# 499995  Other than Kung Fu Tea, I haven't had amazing ...
# 499996  I wish they had one in the westside or for thi...
# 499997  This will be our new favorite spot. Dylan our ...
# 499998  3.5 Stars\n\nEnvironment: The decor is poor, f...
# 499999  I want to tell everyone about an experience I ...
#
# [500000 rows x 3 columns]

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
#from tqdm import tqdm, notebook
from tqdm.auto import tqdm, trange
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import string
import re
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer() 
p_stopwords = stopwords.words('english')

sentiment=True

def preprocess(s):
    if sentiment==True:
        #1. lowercase
        s = s.lower()
        #2. remove HTML
        #soup = BeautifulSoup(s,'lxml')
        #html_free = soup.get_text()
        #3. remove duplicate characters
        #reg = re.sub(r'([a-z])\1+', r'\1', s)
        #3. Remove punctuation & Tokenize
        #cleanr = re.compile('<.*?>')
        #s = re.sub(cleanr, '', s)
        no_punct = "".join([c for c in s if c not in string.punctuation])
        tokenizer = RegexpTokenizer(r'\w+')
        tokens = tokenizer.tokenize(no_punct)    
        # rem_url=re.sub(r'http\S+', '',cleantext)
        # rem_num = re.sub('[0-9]+', '', rem_url)
        #4. Remove stopwords
        filtered_words = [w for w in tokens if w not in stopwords]
        #5. lemmatize/stem words
        final_words=[lemmatizer.lemmatize(w) for w in filtered_words]
        #final_words=[stemmer.stem(w) for w in filtered_words]
    else:
        #1. lowercase
        s = s.lower()
        #2. remove HTML
        soup = BeautifulSoup(s,'lxml')
        html_free = soup.get_text()
        #3. remove duplicate characters
        reg = re.sub(r'([a-z])\1+', r'\1', s)
        tokenizer = RegexpTokenizer(r'\w+')
        final_words = tokenizer.tokenize(reg)   
    return " ".join(final_words)

tqdm.pandas()
d_pre['reviews']=d_pre['reviews'].progress_map(lambda s:preprocess(s))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/imbottlebird/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/imbottlebird/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# HBox(children=(IntProgress(value=0, max=846), HTML(value='')))

# %%
pd.DataFrame({'from': df_review['text'], 'to': df_pre['text']})
# Out:
#                                                      from  \
# 0       As someone who has worked with many museums, I...
# 1       I am actually horrified this place is still in...
# 2       I love Deagan's. I do. I really do. The atmosp...
# 3       Dismal, lukewarm, defrosted-tasting "TexMex" g...
# 4       Oh happy day, finally have a Canes near my cas...
# ...                                                   ...
# 499995  Other than Kung Fu Tea, I haven't had amazing ...
# 499996  I wish they had one in the westside or for thi...
# 499997  This will be our new favorite spot. Dylan our ...
# 499998  3.5 Stars\n\nEnvironment: The decor is poor, f...
# 499999  I want to tell everyone about an experience I ...
#
#                                                        to
# 0       someone worked many museum eager visit galery ...
# 1       actualy horified place stil busines 3 year old...
# 2       love deagans realy atmosphere cozy festive shr...
# 3       dismal lukewarm defrostedtasting texmex glop m...
# 4       oh hapy day finaly cane near casa yes others g...
# ...                                                   ...
# 499995  kung fu tea havent amazing boba long time firs...
# 499996  wish one westside case boba shop let start tar...
# 499997  wil new favorite spot dylan waitres absolutely...
# 499998  35 star environment decor por flor sometimes o...
# 499999  want tel everyone experience tuesday evening e...
#
# [500000 rows x 2 columns]

# %%
#df_comb=df_comb.drop(df_comb.columns[[0]], axis=1)
#df = df.drop(df.columns[[0, 1, 3]], axis=1)
df_comb_sm
# Out:
#                           business_name  stars  \
# 0          Bellagio Gallery of Fine Art    2.0
# 1                        Rio Hair Salon    1.0
# 2                Deagan's Kitchen & Bar    5.0
# 3               Cabo Mexican Restaurant    1.0
# 4        Raising Cane's Chicken Fingers    4.0
# ...                                 ...    ...
# 2999995                      W Montréal    5.0
# 2999996                Bacchanal Buffet    1.0
# 2999997                         Güloglu    4.0
# 2999998      Cold Beers & Cheeseburgers    1.0
# 2999999         Ninja Sushi And Hibachi    4.0
#
#                                                       text
# 0        someon work mani museum eager visit galleri re...
# 1        actual horrifi place still busi year old son n...
# 2        love deagan realli atmosph cozi festiv shrimp ...
# 3        dismal lukewarm defrost tast texmex glop mumbl...
# 4        happi day final cane near casa gripe drive thr...
# ...                                                    ...
# 2999995  incred servic hotel contact local bakeri birth...
# 2999996  god avoid oyster first wife stood line hour pa...
# 2999997  stumbl upon place yesterday drive marco panini...
# 2999998  one worst cold beer cheeseburg frequent one ol...
# 2999999  real nice littl place yummi sushi wine beer sa...
#
# [3000000 rows x 3 columns]

# %%
df_pre.to_csv('data/pre_yelp_500k.csv', index=False)

# %%
csv_df = pd.read_csv('data/yelp_pre.csv')
#csv_df.index +=1
#csv_df.drop(['Unnamed: 0'],axis=1)
csv_df
# Out:
#                    business_id                   business_name  stars  \
# 0       -MhfebM0QIsKt87iDN-FNw    Bellagio Gallery of Fine Art    2.0
# 1       lbrU8StCq3yDfr-QMnGrmQ                  Rio Hair Salon    1.0
# 2       HQl28KMwrEKHqhFrrDqVNQ          Deagan's Kitchen & Bar    5.0
# 3       5JxlZaqCnk1MnbgRirs40Q         Cabo Mexican Restaurant    1.0
# 4       IS4cv902ykd8wj1TR0N3-A  Raising Cane's Chicken Fingers    4.0
# ...                        ...                             ...    ...
# 499995  IhNASEZ3XnBHmuuVnWdIwA                    Brew Tea Bar    5.0
# 499996  IhNASEZ3XnBHmuuVnWdIwA                    Brew Tea Bar    5.0
# 499997  7HbKKqXtZUjf6uVSHZ8wyw                 Let's Meat Kbbq    5.0
# 499998  DvelUmIuBmfbt95frynYsA          Yummy Dumpling and BBQ    3.0
# 499999  lmxA0dJM0XsPCIHPXhEQ-g                        Sake Rok    5.0
#
#                                                      text
# 0       as someone who has worked with many museums i ...
# 1       i am actually horrified this place is still in...
# 2       i love deagan s i do i really do the atmospher...
# 3       dismal lukewarm defrosted tasting texmex glop ...
# 4       oh happy day finally have a canes near my casa...
# ...                                                   ...
# 499995  other than kung fu tea i haven t had amazing b...
# 499996  i wish they had one in the westside or for thi...
# 499997  this will be our new favorite spot dylan our w...
# 499998  3 5 stars environment the decor is poor floor ...
# 499999  i want to tell everyone about an experience i ...
#
# [500000 rows x 4 columns]

# %%
df_comb['business_name'] = df_comb['business_id'].map(df_biz.set_index('business_id')['name'])
df_comb = df_comb[['business_id','business_name','stars','text']]
df_comb
